# %%
import sys
from src.utils.utils import leer_parquet
from src.load.export_sentimientos_pbi import orquestador

def main():
    #orquestador()
    archivo = "sentimientos_pbi.parquet"
    parquet_file =leer_parquet(archivo)

    print(type(parquet_file))


if __name__ == "__main__":
    try:
        main()
    except KeyboardInterrupt:
        sys.exit(130)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import sys
# ----> 2 from src.utils.utils import leer_parquet
#       3 from src.load.export_sentimientos_pbi import orquestador
#       4
#       5 def main():
#
# File c:\Users\genesys\Documents\Proyectos\data_encuesta_emilia\Sentimientos_Emilia\src\utils\utils.py:3
#       1 from pathlib import Path
#       2 import pandas as pd
# ----> 3 from config.config import settings
#       4 from config.log_config import logger
#       6 def leer_parquet(file: str | Path) -> pd.DataFrame:
#
# File c:\Users\genesys\Documents\Proyectos\data_encuesta_emilia\Sentimientos_Emilia\config\config.py:3
#       1 #config/config.py
#       2 from typing import Optional
# ----> 3 from pydantic import Field,SecretStr
#       4 from pydantic_settings import BaseSettings,SettingsConfigDict
#       5 from pathlib import Path
#
# ModuleNotFoundError: No module named 'pydantic'
